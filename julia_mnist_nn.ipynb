# %%
# Fluxなど必要なライブラリをインポート
using Flux
using Flux: onehotbatch, onecold, crossentropy, throttle
using Statistics
using Base.Iterators: repeated

# %%
# MNISTデータを取得

# 訓練データ
train_images = Flux.Data.MNIST.images(:train)
train_labels = Flux.Data.MNIST.labels(:train)

# テストデータ
test_images = Flux.Data.MNIST.images(:test)
test_labels = Flux.Data.MNIST.labels(:test);
# Out:
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data /Users/hagiwararyo/.julia/packages/Flux/Zz9RI/src/data/Data.jl:16
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data /Users/hagiwararyo/.julia/packages/Flux/Zz9RI/src/data/Data.jl:16
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data /Users/hagiwararyo/.julia/packages/Flux/Zz9RI/src/data/Data.jl:16
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data /Users/hagiwararyo/.julia/packages/Flux/Zz9RI/src/data/Data.jl:16

# %%
train_images[100]
# Out:
# 28×28 Array{Gray{N0f8},2} with eltype ColorTypes.Gray{FixedPointNumbers.N0f8}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %%
# 28×28の二次元画像を784の一次元に変換
X_train = hcat(float.(reshape.(train_images, :))...) 

# ワンホットエンコーディング
Y_train = onehotbatch(train_labels, 0:9) ;

# %%
# モデル作成 784->32->relu->10->softmax
model = Chain(Dense(28^2, 32, relu), Dense(32, 10), softmax)
# Out:
# Chain(
#   Dense(784, 32, relu),                 # 25_120 parameters
#   Dense(32, 10),                        # 330 parameters
#   NNlib.softmax,
# )                   # Total: 4 arrays, 25_450 parameters, 99.664 KiB.

# %%
# 損失関数、最適化、データセット、精度計算
loss(x, y) = crossentropy(model(x), y) 
optim = ADAM()
dataset = repeated((X_train,Y_train),200) 
evalcb = () -> @show(loss(X_train, Y_train)) 
accuracy(x, y) = mean(onecold(model(x)) .== onecold(y));

# %%
# 訓練
# 結構時間かかる
Flux.train!(loss, params(model), dataset, optim, cb = throttle(evalcb, 10));
# Out:
# loss(X_train, Y_train) = 2.271378019291697
# loss(X_train, Y_train) = 1.8596014660333002
# loss(X_train, Y_train) = 1.4577232683358645
# loss(X_train, Y_train) = 1.1713244011638808
# loss(X_train, Y_train) = 0.9475548683467208
# loss(X_train, Y_train) = 0.7841306068439364
# loss(X_train, Y_train) = 0.6571190471596838
# loss(X_train, Y_train) = 0.5811707362545664
# loss(X_train, Y_train) = 0.5261085336188817
# loss(X_train, Y_train) = 0.48472064860596853
# loss(X_train, Y_train) = 0.45265575461616064
# loss(X_train, Y_train) = 0.4271252389304644
# loss(X_train, Y_train) = 0.4062232466778854
# loss(X_train, Y_train) = 0.3864211249484466
# loss(X_train, Y_train) = 0.3698345725196808
# loss(X_train, Y_train) = 0.3573326368141663
# loss(X_train, Y_train) = 0.3448280165451945
# loss(X_train, Y_train) = 0.33382260557501153
# loss(X_train, Y_train) = 0.3251710911391685
# loss(X_train, Y_train) = 0.31619921930935835
# loss(X_train, Y_train) = 0.3080328795706118
# loss(X_train, Y_train) = 0.30144957690078567
# loss(X_train, Y_train) = 0.2944725782911184
# loss(X_train, Y_train) = 0.28799076441605553
# loss(X_train, Y_train) = 0.28266189017469245
# loss(X_train, Y_train) = 0.27692067272780185
# loss(X_train, Y_train) = 0.2714968500428504

# %%
test_X = hcat(float.(reshape.(test_images, :))...)
test_Y = onehotbatch(test_labels, 0:9)

@show accuracy(test_X, test_Y)
# Out:
# accuracy(test_X, test_Y) = 0.924
# 0.924
